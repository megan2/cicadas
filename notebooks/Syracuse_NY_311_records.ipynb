# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
import json
import re

# %%
#Read in the original csv file
Syr311 = pd.read_csv('../data/SyracruseCityline_Calls_for_Service.csv', low_memory=False)

##Data source: https://data.syrgov.net/datasets/0aa5fcd76dbd4f2cabf2aeb1ddd0179e_0/about

# %%
Syr311.info() #57110 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57110 entries, 0 to 57109
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   complaint_number               57110 non-null  object
#  1   open_date                      57110 non-null  object
#  2   close_date                     57110 non-null  object
#  3   complaint_type_name            57110 non-null  object
#  4   status_type_name               57110 non-null  object
#  5   department_name                57110 non-null  object
#  6   received_via_type_name         57110 non-null  object
#  7   identifier                     50250 non-null  object
#  8   number                         50248 non-null  object
#  9   address                        50250 non-null  object
#  10  zip                            50248 non-null  float64
#  11  location                       6867 non-null   object
#  12  nearest_address                1807 non-null   object
#  13  nearest_address1               175 non-null    object
#  14  cross_street_1                 524 non-null    object
#  15  cross_street_2                 135 non-null    object
#  16  user_defined_action_type_name  54491 non-null  object
#  17  ObjectId                       57110 non-null  int64
# dtypes: float64(1), int64(1), object(16)
# memory usage: 7.8+ MB

# %%
#convert times to datetimes
Syr311['open_date'] = pd.to_datetime(Syr311['open_date'])

# %%
#what is the date range covered in this current dataframe?
Syr311 = Syr311.sort_values(['open_date'],ascending=True)
#2017/01/09 - 2019-06-26
Syr311.tail()
# Out:
#   complaint_number                        open_date              close_date  \
# 4       2019-17440        2019-06-23 14:22:41+00:00  2019/06/23 04:00:00+00
# 3       2019-17408 2019-06-24 02:41:55.790000+00:00  2019/06/26 04:00:00+00
# 2       2019-17480 2019-06-24 16:01:21.833000+00:00  2019/06/25 04:00:00+00
# 1       2019-17544 2019-06-24 18:33:32.877000+00:00  2019/06/26 04:00:00+00
# 0       2019-17565 2019-06-24 19:08:39.597000+00:00  2019/06/26 04:00:00+00
#
#          complaint_type_name status_type_name       department_name  \
# 4              Sewer Back Up        Completed          DPW - Sewers
# 3          Pot Holes in Road        Completed   DPW - Street Repair
# 2   Street Paving-Patch/Misc        Completed   DPW - Street Repair
# 1  Traffic Sign Req -General        Completed  DPW - Transportation
# 0  Traffic Signl Special Req        Completed  DPW - Transportation
#
#   received_via_type_name    identifier number         address      zip  \
# 4               Cityline  024.-18-25.0    169  Forest Hill Dr  13206.0
# 3                 Online  101.-18-01.4    110       Fabius St  13204.0
# 2               Cityline           NaN    NaN             NaN      NaN
# 1               Cityline           NaN    NaN             NaN      NaN
# 0               Cityline           NaN    NaN             NaN      NaN
#
#                               location nearest_address nearest_address1  \
# 4                                  NaN             NaN              NaN
# 3                                  NaN             NaN              NaN
# 2                  Teall Ave, Syracuse             NaN              NaN
# 1               Fayette St E, Syracuse            1107              NaN
# 0  James St & Marlborough Rd, Syracuse             NaN              NaN
#
#   cross_street_1 cross_street_2 user_defined_action_type_name  ObjectId
# 4            NaN            NaN                Crew Responded         5
# 3            NaN            NaN            Repaired Hot Patch         4
# 2            NaN            NaN            Repaired Hot Patch         3
# 1            NaN            NaN                Crew Responded         2
# 0            NaN            NaN           Repaired / Restored         1

# %%
#Breaking apart the datetime to date and time (don't need to include the time)

Syr311['Date'] = [d.date() for d in Syr311['open_date']]
Syr311['Date'] = pd.to_datetime(Syr311['Date'])
Syr311.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57110 entries, 57032 to 0
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   complaint_number               57110 non-null  object
#  1   open_date                      57110 non-null  datetime64[ns, UTC]
#  2   close_date                     57110 non-null  object
#  3   complaint_type_name            57110 non-null  object
#  4   status_type_name               57110 non-null  object
#  5   department_name                57110 non-null  object
#  6   received_via_type_name         57110 non-null  object
#  7   identifier                     50250 non-null  object
#  8   number                         50248 non-null  object
#  9   address                        50250 non-null  object
#  10  zip                            50248 non-null  float64
#  11  location                       6867 non-null   object
#  12  nearest_address                1807 non-null   object
#  13  nearest_address1               175 non-null    object
#  14  cross_street_1                 524 non-null    object
#  15  cross_street_2                 135 non-null    object
#  16  user_defined_action_type_name  54491 non-null  object
#  17  ObjectId                       57110 non-null  int64
#  18  Date                           57110 non-null  datetime64[ns]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(1), int64(1), object(15)
# memory usage: 8.7+ MB

# %%
#Periodical Cicadas are confirmed in Onondaga County for Brood VII (2018), Syracuse is in Onondaga County.
#Trimming to 2017 - 2019 relevant months


Syr311trim = Syr311[Syr311['Date'] > dt.datetime(2017,5,1)]
Syr311trim = Syr311trim[Syr311trim['Date'] < dt.datetime(2019,7,1)]

# %%
Syr311trim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48612 entries, 48614 to 0
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   complaint_number               48612 non-null  object
#  1   open_date                      48612 non-null  datetime64[ns, UTC]
#  2   close_date                     48612 non-null  object
#  3   complaint_type_name            48612 non-null  object
#  4   status_type_name               48612 non-null  object
#  5   department_name                48612 non-null  object
#  6   received_via_type_name         48612 non-null  object
#  7   identifier                     42897 non-null  object
#  8   number                         42895 non-null  object
#  9   address                        42897 non-null  object
#  10  zip                            42895 non-null  float64
#  11  location                       5722 non-null   object
#  12  nearest_address                1652 non-null   object
#  13  nearest_address1               130 non-null    object
#  14  cross_street_1                 512 non-null    object
#  15  cross_street_2                 121 non-null    object
#  16  user_defined_action_type_name  46623 non-null  object
#  17  ObjectId                       48612 non-null  int64
#  18  Date                           48612 non-null  datetime64[ns]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(1), int64(1), object(15)
# memory usage: 7.4+ MB

# %% [markdown]
# # Isolating data to months of May and June for each year

# %%
#2017
Syr3112017 = Syr311trim[Syr311trim['Date'] > dt.datetime(2017,5,1)]
Syr3112017 = Syr3112017[Syr3112017['Date'] < dt.datetime(2017,7,1)]

# %%
Syr3112017.tail(20)
# Out:
#       complaint_number                        open_date  \
# 43942       2017-18796 2017-06-30 18:15:10.180000+00:00
# 43941       2017-18800 2017-06-30 18:19:42.950000+00:00
# 43940       2017-18801 2017-06-30 18:20:07.713000+00:00
# 43939       2017-18802 2017-06-30 18:20:33.767000+00:00
# 43938       2017-18803 2017-06-30 18:21:04.817000+00:00
# 43937       2017-18805 2017-06-30 18:22:08.257000+00:00
# 43936       2017-18808 2017-06-30 18:37:25.520000+00:00
# 43933       2017-18810 2017-06-30 18:39:25.490000+00:00
# 43930       2017-18811 2017-06-30 18:51:30.260000+00:00
# 43907       2017-18812 2017-06-30 18:52:33.503000+00:00
# 43903       2017-18813 2017-06-30 18:54:00.537000+00:00
# 43899       2017-18815 2017-06-30 19:07:31.087000+00:00
# 43894       2017-18818 2017-06-30 19:10:33.160000+00:00
# 43862       2017-18817 2017-06-30 19:12:28.777000+00:00
# 43857       2017-18820 2017-06-30 19:12:36.980000+00:00
# 43852       2017-18823 2017-06-30 19:59:03.750000+00:00
# 43847       2017-18825 2017-06-30 20:02:15.880000+00:00
# 43841       2017-19777        2017-06-30 20:18:31+00:00
# 43835       2017-18826 2017-06-30 20:31:58.120000+00:00
# 43830       2017-18827 2017-06-30 20:33:08.103000+00:00
#
#                    close_date        complaint_type_name status_type_name  \
# 43942  2017/07/12 04:00:00+00  CleanUp Rqst: Public Prop        Completed
# 43941  2017/07/10 04:00:00+00                 Trash Skip        Completed
# 43940  2017/07/06 04:00:00+00   Blue Bin: request new BB        Completed
# 43939  2017/07/05 04:00:00+00       Bulk Household Items        Completed
# 43938  2017/07/05 04:00:00+00   Sanitation/Special Reqst        Completed
# 43937  2017/07/10 04:00:00+00       Bulk Household Items        Completed
# 43936  2017/07/03 04:00:00+00   Blue Bin: request new BB        Completed
# 43933  2017/07/06 04:00:00+00       Bulk Household Items        Completed
# 43930  2017/07/05 04:00:00+00       Bulk Household Items        Completed
# 43907  2017/07/12 04:00:00+00      Illegal Trash Set Out        Completed
# 43903  2017/07/12 04:00:00+00      Illegal Trash Set Out        Completed
# 43899  2017/07/03 04:00:00+00   Blue Bin: request new BB        Completed
# 43894  2017/07/06 04:00:00+00  Transport Special Request        Completed
# 43862  2017/07/05 04:00:00+00       Bulk Household Items        Completed
# 43857  2017/07/05 04:00:00+00       Bulk Household Items        Completed
# 43852  2017/07/05 04:00:00+00       Bulk Household Items        Completed
# 43847  2017/07/03 04:00:00+00         Catch Basin: Clean        Completed
# 43841  2017/06/30 04:00:00+00  Repair ManHoleCover/Grate        Completed
# 43835  2018/01/26 05:00:00+00   Street Paving-Patch/Misc        Completed
# 43830  2017/07/03 04:00:00+00   Blue Bin: request new BB        Completed
#
#             department_name received_via_type_name    identifier  number  \
# 43942             DPW - ISR               Cityline           NaN     NaN
# 43941      DPW - Sanitation               Cityline  105.-01-38.0     438
# 43940      DPW - Sanitation               Cityline  113.-13-05.0     111
# 43939      DPW - Sanitation               Cityline  045.-02-14.0  250-52
# 43938      DPW - Sanitation               Cityline           NaN     NaN
# 43937      DPW - Sanitation               Cityline  007.-23-09.0    1013
# 43936      DPW - Sanitation               Cityline  059.-05-14.0     327
# 43933      DPW - Sanitation               Cityline  061.-01-05.2  316-24
# 43930      DPW - Sanitation               Cityline  053.-16-06.0    1120
# 43907             DPW - ISR               Cityline  020.-08-11.0     240
# 43903             DPW - ISR               Cityline           NaN     NaN
# 43899      DPW - Sanitation               Cityline  058.-09-29.0     207
# 43894  DPW - Transportation               Cityline           NaN     NaN
# 43862      DPW - Sanitation               Cityline  055.-18-11.0     103
# 43857      DPW - Sanitation               Cityline  045.-17-02.0  100-02
# 43852      DPW - Sanitation               Cityline  053.-05-06.0    1220
# 43847          DPW - Sewers               Cityline  086.-26-11.0     111
# 43841          DPW - Sewers               Cityline           NaN     NaN
# 43835   DPW - Street Repair               Cityline           NaN     NaN
# 43830      DPW - Sanitation               Cityline  053.-01-10.0  829-31
#
#                          address      zip  \
# 43942                        NaN      NaN
# 43941               Wilkinson St  13204.0
# 43940                 Morgan Ave  13204.0
# 43939                Fellows Ave  13210.0
# 43938                        NaN      NaN
# 43937             First North St  13208.0
# 43936                 Thurber St  13210.0
# 43933             Brighton Ave E  13210.0
# 43930           Westmoreland Ave  13210.0
# 43907               Stafford Ave  13206.0
# 43903                        NaN      NaN
# 43899                  Moore Ave  13210.0
# 43894                        NaN      NaN
# 43862               Haffenden Rd  13210.0
# 43857                Victoria Pl  13210.0
# 43852  Euclid Ave & Cumberland A  13210.0
# 43847                  Cheney St  13205.0
# 43841                        NaN      NaN
# 43835                        NaN      NaN
# 43830                Westcott St  13210.0
#
#                                   location nearest_address nearest_address1  \
# 43942                 Stedman St, Syracuse             NaN              NaN
# 43941                                  NaN             NaN              NaN
# 43940                                  NaN             NaN              NaN
# 43939                                  NaN             NaN              NaN
# 43938                Euclid Terr, Syracuse             NaN              NaN
# 43937                                  NaN             NaN              NaN
# 43936                                  NaN             NaN              NaN
# 43933                                  NaN             NaN              NaN
# 43930                                  NaN             NaN              NaN
# 43907                                  NaN             NaN              NaN
# 43903  Butternut St & Peter St &, Syracuse             NaN              NaN
# 43899                                  NaN             NaN              NaN
# 43894         Franklin St N #208, Syracuse             NaN              NaN
# 43862                                  NaN             NaN              NaN
# 43857                                  NaN             NaN              NaN
# 43852                                  NaN             NaN              NaN
# 43847                                  NaN             NaN              NaN
# 43841  Bellevue Ave & Clairemont, Syracuse             NaN              NaN
# 43835                Waverly Ave, Syracuse             NaN              NaN
# 43830                                  NaN             NaN              NaN
#
#       cross_street_1 cross_street_2 user_defined_action_type_name  ObjectId  \
# 43942            NaN            NaN                    Cleaned Up     43943
# 43941            NaN            NaN                     Picked Up     43942
# 43940            NaN            NaN                     Delivered     43941
# 43939            NaN            NaN                     Picked Up     43940
# 43938            NaN            NaN                     Picked Up     43939
# 43937            NaN            NaN                     Picked Up     43938
# 43936            NaN            NaN                     Delivered     43937
# 43933            NaN            NaN                     Picked Up     43934
# 43930            NaN            NaN                     Picked Up     43931
# 43907            NaN            NaN                    Compliance     43908
# 43903            NaN            NaN                    Compliance     43904
# 43899            NaN            NaN                     Delivered     43900
# 43894            NaN            NaN                Crew Responded     43895
# 43862            NaN            NaN                     Picked Up     43863
# 43857            NaN            NaN                     Picked Up     43858
# 43852            NaN            NaN                     Picked Up     43853
# 43847            NaN            NaN                Crew Responded     43848
# 43841            NaN            NaN                Crew Responded     43842
# 43835            NaN            NaN        Repaired DuraPatcher 1     43836
# 43830            NaN            NaN                     Delivered     43831
#
#             Date
# 43942 2017-06-30
# 43941 2017-06-30
# 43940 2017-06-30
# 43939 2017-06-30
# 43938 2017-06-30
# 43937 2017-06-30
# 43936 2017-06-30
# 43933 2017-06-30
# 43930 2017-06-30
# 43907 2017-06-30
# 43903 2017-06-30
# 43899 2017-06-30
# 43894 2017-06-30
# 43862 2017-06-30
# 43857 2017-06-30
# 43852 2017-06-30
# 43847 2017-06-30
# 43841 2017-06-30
# 43835 2017-06-30
# 43830 2017-06-30

# %%
#2018 - cicada year
Syr3112018 = Syr311trim[Syr311trim['Date'] > dt.datetime(2018,5,1)]
Syr3112018 = Syr3112018[Syr3112018['Date'] < dt.datetime(2018,7,1)]

# %%
#2019
Syr3112019 = Syr311trim[Syr311trim['Date'] > dt.datetime(2019,5,1)]
Syr3112019 = Syr3112019[Syr3112019['Date'] < dt.datetime(2019,7,1)]

# %%
#Bring them back to a single dataset
years = [Syr3112017, Syr3112018, Syr3112019]
Syr311_final = pd.concat(years)

# %%
Syr311_final.info #12440 rows

# %% [markdown]
# ## Getting relevant requests / types of calls

# %%
Syr311_final['complaint_type_name'].unique()
# Out:
# array(['Pot Holes in Road', 'Tire Pickup (4/yr)', 'Sewer Back Up',
#        'Blue Bin: request new BB', 'Trash Skip', 'Bulk Household Items',
#        'Traffic Sign Req -General', 'Quad 4 ConstrDebrisPickUp',
#        'Metal Household Items', 'Tree/Limb/Stump Removal',
#        'Blue Bin Skip', 'Sewer Dept/Special Reqst',
#        'Tree Trimming Request', 'Illegal Trash Set Out',
#        'Illegal TV Set Out', 'Transport Special Request',
#        'Catch Basin: Clean', 'Overgrown Veg - Public',
#        'Street Repair Special Req', 'Street Paving-Patch/Misc',
#        'Sidewalk Condition', 'Sanitation/Special Reqst',
#        'Repair ManHoleCover/Grate', 'Driveway Damage', 'Jet Lateral/Main',
#        'Repair Sewer Pipes-Caps', 'Tree Inspect/Problem Req',
#        'CleanUp Rqst: Public Prop', 'Sewer Cave-in',
#        'Emergency UFPO/NAT.GRID', 'Traffic Signl Special Req',
#        'Parks Maint/General', 'Barricade Pickup',
#        'Trash/Debris-Private, Occ', 'Repair Creek Fencing',
#        'Creeks Repair Cleaning', 'Lateral Install/Repair',
#        'Complaint Reqst - General', 'Curbing Install / Repair',
#        'Corners Need Snow Removal', 'Building/Grounds Special',
#        'Trash Can Taken / Damaged', 'Street Clean Special Req',
#        'DeadAnimal in Right ofWay'], dtype=object)

# %%
# What types of Phone Calls indicate bad behavior and/or an annoyed populace?
relevant_requests = ['Pot Holes in Road',
                    'Trash Skip', 
                     'Bulk Household Items', ##look into definition of household items complaints
                     'Metal Household Items'
                     'Traffic Sign Req -General',
                     'Blue Bin Skip',
                     'Illegal Trash Set Out',
                    'Illegal TV Set Out',
                     'Catch Basin: Clean', 
                     'Overgrown Veg - Public',
                   'Street Repair Special Req',
                     'Sidewalk Condition',
                     'Repair ManHoleCover/Grate', 
                     'Driveway Damage',
                     'Barricade Pickup',
                     'Trash/Debris-Private, Occ', 'Repair Creek Fencing',
       'Creeks Repair Cleaning', 'Complaint Reqst - General', 'Trash Can Taken / Damaged', 'Street Clean Special Req',
       'DeadAnimal in Right ofWay',
                     'Corners Need Snow Removal' #why would this be happening in summer months??
                     
                    ]

# %%
print(relevant_requests)
# Out:
# ['Pot Holes in Road', 'Trash Skip', 'Bulk Household Items', 'Metal Household ItemsTraffic Sign Req -General', 'Blue Bin Skip', 'Illegal Trash Set Out', 'Illegal TV Set Out', 'Catch Basin: Clean', 'Overgrown Veg - Public', 'Street Repair Special Req', 'Sidewalk Condition', 'Repair ManHoleCover/Grate', 'Driveway Damage', 'Barricade Pickup', 'Trash/Debris-Private, Occ', 'Repair Creek Fencing', 'Creeks Repair Cleaning', 'Complaint Reqst - General', 'Trash Can Taken / Damaged', 'Street Clean Special Req', 'DeadAnimal in Right ofWay', 'Corners Need Snow Removal']

# %%
#trim dataframe to match the list of relevant request types

Syr311_final = Syr311_final[(Syr311_final['complaint_type_name'].isin(relevant_requests))]

# %%
Syr311_final.info() #6869 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6869 entries, 48614 to 3
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   complaint_number               6869 non-null   object
#  1   open_date                      6869 non-null   datetime64[ns, UTC]
#  2   close_date                     6869 non-null   object
#  3   complaint_type_name            6869 non-null   object
#  4   status_type_name               6869 non-null   object
#  5   department_name                6869 non-null   object
#  6   received_via_type_name         6869 non-null   object
#  7   identifier                     5898 non-null   object
#  8   number                         5898 non-null   object
#  9   address                        5898 non-null   object
#  10  zip                            5898 non-null   float64
#  11  location                       971 non-null    object
#  12  nearest_address                265 non-null    object
#  13  nearest_address1               19 non-null     object
#  14  cross_street_1                 92 non-null     object
#  15  cross_street_2                 27 non-null     object
#  16  user_defined_action_type_name  6533 non-null   object
#  17  ObjectId                       6869 non-null   int64
#  18  Date                           6869 non-null   datetime64[ns]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(1), int64(1), object(15)
# memory usage: 1.0+ MB

# %% [markdown]
# ## Export

# %%
#Save as a csv
Syr311_final.to_csv('Syr311_final.csv', index = False, header=True)
